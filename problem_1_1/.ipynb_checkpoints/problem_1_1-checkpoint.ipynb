# %%
import hashlib

from sklearn.datasets import load_boston
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
def boston_as_dataframe():
    bos = load_boston(return_X_y=True)
    data = bos[0]
    target = bos[1]
    df = pd.DataFrame(data=data,
                      columns=["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B 1000", "LSTAT"])
    df["TARGET"] = target
    return df, target

# %%
df, target = boston_as_dataframe()
df_with_index = df.reset_index()

print(df_with_index.head(5))
print(df_with_index.describe())
df_with_index.hist(bins=50, figsize=(20, 15))
plt.show()
# Out:
#    index     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0      0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1      1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2      2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3      3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4      4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO  B 1000  LSTAT  TARGET
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2
#             index        CRIM          ZN       INDUS        CHAS         NOX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   252.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      0.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    126.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    252.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    378.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    505.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# std      0.702617   28.148861    2.105710    8.707259  168.537116    2.164946
# min      3.561000    2.900000    1.129600    1.000000  187.000000   12.600000
# 25%      5.885500   45.025000    2.100175    4.000000  279.000000   17.400000
# 50%      6.208500   77.500000    3.207450    5.000000  330.000000   19.050000
# 75%      6.623500   94.075000    5.188425   24.000000  666.000000   20.200000
# max      8.780000  100.000000   12.126500   24.000000  711.000000   22.000000
#
#            B 1000       LSTAT      TARGET
# count  506.000000  506.000000  506.000000
# mean   356.674032   12.653063   22.532806
# std     91.294864    7.141062    9.197104
# min      0.320000    1.730000    5.000000
# 25%    375.377500    6.950000   17.025000
# 50%    391.440000   11.360000   21.200000
# 75%    396.225000   16.955000   25.000000
# max    396.900000   37.970000   50.000000

# %%
# Create a hash on the index for the test set in order to reproducibly create the test set.

def test_set_check(identifier, test_ratio, hash):
    return hash(np.int64(identifier)).digest()[-1] < 256 * test_ratio

def split_train_test(data, test_ratio, id_col, hash=hashlib.md5):
    ids = data[id_col]
    in_test_set = ids.apply(lambda id_: test_set_check(id_, test_ratio, hash))
    
    # shuffled_indices = np.random.permutation(len(data))
    # test_set_size = int(len(data) * test_ratio)
    # test_indices = shuffled_indices[:test_set_size]
    # train_indices = shuffled_indices[test_set_size:]
    return data.loc[~in_test_set], data.loc[in_test_set]

train, test = split_train_test(df_with_index, 0.2, "index")
print(train)
print()
print(test)
# Out:
#      index     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0        0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1        1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2        2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3        3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 6        6  0.08829  12.5   7.87   0.0  0.524  6.012  66.6  5.5605  5.0
# ..     ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501    501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0
# 502    502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0
# 503    503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0
# 504    504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0
# 505    505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0
#
#        TAX  PTRATIO  B 1000  LSTAT  TARGET
# 0    296.0     15.3  396.90   4.98    24.0
# 1    242.0     17.8  396.90   9.14    21.6
# 2    242.0     17.8  392.83   4.03    34.7
# 3    222.0     18.7  394.63   2.94    33.4
# 6    311.0     15.2  395.60  12.43    22.9
# ..     ...      ...     ...    ...     ...
# 501  273.0     21.0  391.99   9.67    22.4
# 502  273.0     21.0  396.90   9.08    20.6
# 503  273.0     21.0  396.90   5.64    23.9
# 504  273.0     21.0  393.45   6.48    22.0
# 505  273.0     21.0  396.90   7.88    11.9
#
# [410 rows x 15 columns]
#
#      index     CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD  \
# 4        4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0
# 5        5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0
# 11      11  0.11747  12.5   7.87   0.0  0.524  6.009   82.9  6.2267   5.0
# 20      20  1.25179   0.0   8.14   0.0  0.538  5.570   98.1  3.7979   4.0
# 23      23  0.98843   0.0   8.14   0.0  0.538  5.813  100.0  4.0952   4.0
# ..     ...      ...   ...    ...   ...    ...    ...    ...     ...   ...
# 482    482  5.73116   0.0  18.10   0.0  0.532  7.061   77.0  3.4106  24.0
# 483    483  2.81838   0.0  18.10   0.0  0.532  5.762   40.3  4.0983  24.0
# 486    486  5.69175   0.0  18.10   0.0  0.583  6.114   79.8  3.5459  24.0
# 494    494  0.27957   0.0   9.69   0.0  0.585  5.926   42.6  2.3817   6.0
# 498    498  0.23912   0.0   9.69   0.0  0.585  6.019   65.3  2.4091   6.0
#
#        TAX  PTRATIO  B 1000  LSTAT  TARGET
# 4    222.0     18.7  396.90   5.33    36.2
# 5    222.0     18.7  394.12   5.21    28.7
# 11   311.0     15.2  396.90  13.27    18.9
# 20   307.0     21.0  376.57  21.02    13.6
# 23   307.0     21.0  394.54  19.88    14.5
# ..     ...      ...     ...    ...     ...
# 482  666.0     20.2  395.28   7.01    25.0
# 483  666.0     20.2  392.92  10.42    21.8
# 486  666.0     20.2  392.68  14.98    19.1
# 494  391.0     19.2  396.90  13.59    24.5
# 498  391.0     19.2  396.90  12.92    21.2
#
# [96 rows x 15 columns]

# %%
## Discovery and Visualization
housing = train.copy()
corr_matrix = housing.corr()
corr_matrix["TARGET"].sort_values(ascending=False)

attributes = ["TARGET", "RM", "ZN", "LSTAT", "PTRATIO"]
scatter_matrix(housing[attributes], figsize=(12, 8))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7e7a8653cb9e> in <module>
#       1 ## Discovery and Visualization
# ----> 2 housing = train.copy()
#       3 corr_matrix = housing.corr()
#       4 corr_matrix["TARGET"].sort_values(ascending=False)
#       5
#
# NameError: name 'train' is not defined

# %%
housing = train.drop("TARGET", axis=1)
housing_labels = train["TARGET"].copy()

h1 = housing[housing.isna().any(axis=1)]
h1
# Out:
# Empty DataFrame
# Columns: [index, CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B 1000, LSTAT]
# Index: []

# %% [markdown]
# There are no categorical values in the dataset

# %%
trans_pipeline = Pipeline([('min_max_scale', MinMaxScaler())])
housing_tr = trans_pipeline.fit_transform(housing)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7b055798fd7c> in <module>
#       1 trans_pipeline = Pipeline([('min_max_scale', MinMaxScaler())])
# ----> 2 housing_tr = trans_pipeline.fit_transform(housing)
#
# NameError: name 'housing' is not defined

# %%
lin_reg = LinearRegression()
lin_reg.fit(housing_tr, housing_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9442fa16b14f> in <module>
#       1 lin_reg = LinearRegression()
# ----> 2 lin_reg.fit(housing_tr, housing_labels)
#
# NameError: name 'housing_tr' is not defined

# %%
some_data = housing.iloc[:5]
some_labels = housing_labels[:5]
some_preped_data = trans_pipeline.fit_transform(some_data)
print(f"Predictions: {lin_reg.predict(some_preped_data)}")
print(f"Labels: {list(some_labels)}")
# Out:
# Predictions: [ 26.88449528   9.23566034  28.69149447  21.38386965 -12.86168757]
# Labels: [24.0, 21.6, 34.7, 33.4, 22.9]

# %%
from sklearn.metrics import mean_squared_error

housing_predictions = lin_reg.predict(housing_tr)
lin_mse = mean_squared_error(housing_labels, housing_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 4.315213971873178

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor()
tree_reg.fit(housing_tr, housing_labels)

housing_predictions = tree_reg.predict(housing_tr)
tree_mse = mean_squared_error(housing_labels, housing_predictions)
tree_rmse = np.sqrt(tree_mse)
tree_rmse
# Out:
# 0.0

# %%
from sklearn.model_selection import cross_val_score

tree_scores = cross_val_score(tree_reg, housing_tr, housing_labels, scoring="neg_mean_squared_error", cv=10)
tree_rmse_scores = np.sqrt(-tree_scores)

lin_scores = cross_val_score(lin_reg, housing_tr, housing_labels, scoring="neg_mean_squared_error", cv=10)
lin_rmse_scores = np.sqrt(-lin_scores)

def display_scores(scores):
    print("Scores: ", scores)
    print("Mean: ", scores.mean())
    print("STDEV: ", scores.std())

print("Tree Regressor:")
display_scores(tree_rmse_scores)
print()
print("Linear Regression: ")
display_scores(lin_rmse_scores)
print()
# Out:
# Tree Regressor:
# Scores:  [3.87773507 3.48221965 4.25288998 5.05559338 4.27194478 7.98177803
#  4.78470633 8.5446032  5.38817585 7.25567902]
# Mean:  5.48953252809341
# STDEV:  1.7028909245906383
#
# Linear Regression:
# Scores:  [ 2.67594623  3.91890976  3.38896583  5.69798835  5.00492781  4.89744902
#   2.90525444 10.51542237  5.73138527  3.81666071]
# Mean:  4.855290977868559
# STDEV:  2.149343945736466

# %%
from sklearn.ensemble import RandomForestRegressor
forest_reg = RandomForestRegressor()
forest_reg = forest_reg.fit(housing_tr, housing_labels)

forest_scores = cross_val_score(forest_reg, housing_tr, housing_labels, scoring="neg_mean_squared_error", cv=10)
forest_rmse_scores = np.sqrt(-forest_scores)

print("Forest Regressor:")
display_scores(forest_rmse_scores)
print()
# Out:
# Forest Regressor:
# Scores:  [3.27843942 2.4951783  2.38083492 4.79012928 3.44230734 6.32977404
#  2.9810839  7.61136163 4.23182463 4.2770746 ]
# Mean:  4.181800806405549
# STDEV:  1.6015656877353646

# %%
import os
from sklearn.externals import joblib

def save_models(models):
    for model, name in models:
        joblib.dump(model, os.path.join(name))

def load_models(names):
    models = []
    for name in names:
        m = joblib.load(name)
        models.append((m, name))
    return models
        
models = [(tree_reg, "tree_regressor.pkl"),
          (lin_reg, "linear_regression.pkl"),
          (forest_reg, "random_forest.pkl")]

save_models(models)#, "/home/kevin/bin/machine_learning_project_1/problem_1_1")

m = load_models([m[1] for m in models])

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
    {'n_estimators': [3, 10, 10], 'max_features': [2, 4, 6, 8]},
    {'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [2, 3, 4]}
]

forest_reg = RandomForestRegressor()

grid_search = GridSearchCV(forest_reg, param_grid, cv=5,
                           scoring='neg_mean_squared_error')
grid_search.fit(housing_tr, housing_labels)
print(grid_search.best_params_)
print(grid_search.best_estimator_)

cvres = grid_search.cv_results_

for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# {'max_features': 8, 'n_estimators': 10}
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features=8, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=10, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)
# 6.408518001927576 {'max_features': 2, 'n_estimators': 3}
# 5.244206745566378 {'max_features': 2, 'n_estimators': 10}
# 4.839803563842789 {'max_features': 2, 'n_estimators': 10}
# 4.642091506006264 {'max_features': 4, 'n_estimators': 3}
# 4.921775680956878 {'max_features': 4, 'n_estimators': 10}
# 4.640467254648331 {'max_features': 4, 'n_estimators': 10}
# 5.0489044667495095 {'max_features': 6, 'n_estimators': 3}
# 4.535510673912116 {'max_features': 6, 'n_estimators': 10}
# 4.3784703309517115 {'max_features': 6, 'n_estimators': 10}
# 5.545871288344463 {'max_features': 8, 'n_estimators': 3}
# 4.356735771809653 {'max_features': 8, 'n_estimators': 10}
# 4.192016861351307 {'max_features': 8, 'n_estimators': 10}
# 4.992740800863493 {'bootstrap': False, 'max_features': 2, 'n_estimators': 3}
# 5.347783447829395 {'bootstrap': False, 'max_features': 2, 'n_estimators': 10}
# 5.183440382655327 {'bootstrap': False, 'max_features': 3, 'n_estimators': 3}
# 4.481866091098281 {'bootstrap': False, 'max_features': 3, 'n_estimators': 10}
# 5.429445464205391 {'bootstrap': False, 'max_features': 4, 'n_estimators': 3}
# 4.410803505142301 {'bootstrap': False, 'max_features': 4, 'n_estimators': 10}

# %%
feature_importances = grid_search.best_estimator_.feature_importances_

print(feature_importances)
attributes = ["index", "CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B 1000", "LSTAT"]
print(sorted(zip(attributes, feature_importances), reverse=True, key=lambda x: x[1]))
# Out:
# [0.05112739 0.03441236 0.00121645 0.04244167 0.00061919 0.02791447
#  0.342031   0.01976582 0.02965676 0.00536305 0.03897167 0.02294797
#  0.01286772 0.37066449]
# [('AGE', 0.3420310009051992), ('CRIM', 0.05112738738491174), ('CHAS', 0.04244167294179493), ('PTRATIO', 0.03897166578469685), ('ZN', 0.034412355732769), ('RAD', 0.029656760854300968), ('RM', 0.027914465934989308), ('B 1000', 0.022947965678673278), ('DIS', 0.019765824067511532), ('LSTAT', 0.012867716360385445), ('TAX', 0.005363051519741502), ('INDUS', 0.0012164520392592857), ('NOX', 0.0006191936377506748)]

# %%
final_model = grid_search.best_estimator_

x_test = test.drop("TARGET", axis=1)
y_test = test["TARGET"].copy()

x_test_prepped = trans_pipeline.transform(x_test)
final_predictions = final_model.predict(x_test_prepped)

final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)

print(final_rmse)
# Out:
# 4.7881431247753365
